# %% [markdown]
# # Master Notebook - Complete Fake News Classification Pipeline
#
# This notebook runs the entire pipeline in one place, ensuring all variables are shared.

# %% [markdown]
# ## Step 1: Data Download and Exploration

# %%
# Run notebook 1 code
# %run "01_data_download_and_exploration.ipynb"

# %% [markdown]
# ## Step 2: Preprocessing and Baseline Models

# %%
# Run notebook 2 code
# %run "02_preprocessing_and_baseline.ipynb"

# %% [markdown]
# ## Step 3: CNN Models

# %%
# Run notebook 3 code
# %run "03_cnn_model.ipynb"

# %% [markdown]
# ## Step 4: LSTM Models

# %%
# Run notebook 4 code
# %run "04_lstm_model.ipynb"

# %% [markdown]
# ## Step 5: Transformer Models (Optional)

# %%
# Run notebook 5 code (optional)
# %run "05_transformer_bert.ipynb"

# %% [markdown]
# ## Step 6: Final Comparison

# %%
# Run notebook 6 code
# %run "06_final_comparison_and_poster.ipynb"

# %% [markdown]
# ## Summary
#
# All notebooks have been executed in sequence with shared variables!
